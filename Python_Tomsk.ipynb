# %% [markdown]
# ## Задача 1
#
# Вы получается файл в формате FASTA с нуклеотидной последовательностью, в которой зашифрована аминокислотная последовательность белка.
# Необходимо:
# * прочитать информацию из файла;
# * комплементарно достроить цепь РНК;
#
# Для получения полного балла за задачу необходимо:
# * реализовать код по каждому из пунктов;
# * для работы с массивами использовать numpy;
# * в конце задачи вывести промежуточные результаты;
# * название переменных должно быть связано с задачей (не a, b, c, а напр. dna, rna, prot);

# %%
import pandas as pd
import numpy as np

# %%
# Дополните функцию распаковки.
# Комментариями объясните принципиально важные строки кода.
# Примените функцию.

def fasta(#название файла):
    with open(#название файла) as file:
        #ваш код здесь 
        #часть вашего кода для записи строк в одну (без симбволов '\n')
    return res
        
# Не забудьте удалить или обойти строку, характеризующую последовательность.
# Рекомендуем предварительно открыть файл.

# %%
# Дополните функцию построения последовательности нуклеотидов РНК.
# Комментариями объясните принципиально важные строки кода.
# Примените функцию.
# Выведите промежуточный результат.

def rna(#последовательность нуклеотидов):
    nucleotides = ('A', 'U', 'G', 'C')
    #ваш код здесь
    return res

# %% [markdown]
# # Задача 2
#
# Правила, согласно которым последовтаельность кодонов переводится в последовательность аминокислот, называются генетическим кодом. Согласно ему старт-кодон задаёт рамку считывания - определяется порядок чтения триплетов. Триплеты не перекрываются, идут строго друг за другом. Известно, что если рамка считывания задана неверно, то в последовательности может быть много стоп-кодонов.
# Обычно старт-кодоном выступает AUG (метионин), стоп-кодоны: UAA (охра), UAG (янтарь), UGA (опал).
#
# Необходимо:
# * задать рамку считывания (найти старт-кодон);
# * восстановить последовательность аминокислот используя таблицу стандартного генетического кода;
#
# Для получения полного балла за задачу необходимо:
# * реализовать код по каждому из пунктов;
# * для работы с массивами использовать numpy;
# * в конце задачи вывести промежуточные результаты;
# * название переменных должно быть связано с задачей (не a, b, c, а, напр., dna, rna, prot);

# %%
# Дополните функцию перевода.
# Комментариями объясните принципиально важные строки кода.
# Примените функцию.

aminoacid = {'TTT' : 'F','TTC' : 'F','TTA' : 'L','TTG' : 'L','CTT' : 'L','CTC' : 'L', /n
             'CTA' : 'L','CTG' : 'L','ATT' : 'I','ATC' : 'I','ATA' : 'I','ATG' : 'M', /n
             'GTT' : 'V','GTC' : 'V','GTA' : 'V','GTG' : 'V','TCT' : 'S','TCC' : 'S', /n
             'TCA' : 'S','TCG' : 'S','CCT' : 'P','CCC' : 'P','CCA' : 'P','CCG' : 'P', /n
             'ACT' : 'T','ACC' : 'T','ACA' : 'T','ACG' : 'T','GCT' : 'A','GCG' : 'A', /n
             'GCA' : 'A','GCG' : 'A','TAT' : 'Y','TAC' : 'Y','TAA' : 'STOP','TAG' : 'STOP', /n
             'CAT' : 'H','CAC' : 'H','CAA' : 'Q','CAG' : 'Q','AAT' : 'N','AAC' : 'N', /n
             'AAA' : 'K','AAG' : 'K','GAT' : 'D','GAC' : 'D','GAA' : 'E','GAG' : 'E', /n
             'TGT' : 'C','TGC' : 'C','TGA' : 'STOP','TGG' : 'W','CGT' : 'R','CGC' : 'R', /n
             'CGA' : 'R','CGG' : 'R','AGT' : 'S','AGC' : 'S','AGA' : 'R','AGC' : 'R', /n
             'CGT' : 'G','GGC' : 'G','GGA' : 'G','GGG' : 'G',}

def translation(#рнк):
    #часть кода для поиска старт-кодона 
    protein = np.array[aminoacid[codon] for codon in rna]
    return protein
    
# В функции translation используется list comprehension, он уже прописан в коде, но, возможно, нуждается в доработке.
# Не забудьте явно прописать в коде, что начать построение последовательности надо именно со старт-кодона!

# %% [markdown]
# # Задача 3
#
# Существует несколько полезных серверов для биоинформатиков. С одним из них - SWISS-MODEL мы предлагаем вам поработать. Для выполнения этого пункта вам не понадобится писать код.
#
# https://swissmodel.expasy.org/ - ссылка, по которой вы можете получить доступ к swiss-model.
#
# Необходимо:
#
# * ввести последовательность в поисковую систему;
# * определить, относится ли предложенный белок к уже существующим;
# * занести полученные результаты в таблицу (см. следующий пункт);

# %% [markdown]
# # Задача 4
#
# Для удобства полученные результаты полезно хранить в компактном и лего доступном виде.
#
# Необходимо:
# * создать датафрейм;
# * добавить в него всю полученную информацию, изменить названия столбцов и строк в соответствии с наполнением ячеек;
# * вывести итоговый результат;
#
# Для получения полного балла за задачу необходимо:
# * реализовать код по каждому из пунктов;
# * для работы с массивами использовать numpy;
# * название переменных должно быть связано с задачей (не a, b, c, а, напр., dna, rna, prot);

# %%
#реализуйте код в этой ячейке
